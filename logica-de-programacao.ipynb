# %% [markdown]
# #### Condicional

# %%
idade = 12
def verifica_pode_dirigir(idade):
    if idade >= 18:
        print('Tem permissão para dirigir')
    else:
        print('N tem perm')

# %%
verifica_pode_dirigir(idade)
# Out:
# N tem perm

# %% [markdown]
# #### Tipos em uma lista

# %%
lista = ['Guilherme', 28, True, '18']

for elemento in lista:
    print(type(elemento))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# #### Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = list(range(1, 9))
y = notas_matematica = [8,7,7,8,9,3,2,8]
plt.plot(x, y)
plt.title('Notas de Matemática')
plt.show()
